# %%
import pandas as pd
from vigipy import gps, bcpnn, lasso
from vigipy.utils.data_prep import convert, convert_binary, convert_multi_item
from vigipy.utils.expectations import test_dispersion

# %% [markdown]
# ## Loading Data and Formatting for Analysis
#
# The provided sample dataset `DYB_SUBSET.csv` is a selection of medical device report outcomes from the FDA MAUDE database. The data was automatically extracted from the original user report with a LLAMA3-based LLM and has only been minimally cleaned and processed. Unless you manually specify in the conversion functions, it is assumed that your input dataframe will have at least 3 columns: `AE` for the adverse event or problem, `name` for the brand name or generic name of the product used and `count` for the number of times that particular AE-device/drug combination occurs in the reporting system.

# %%
# Read and change column names to the default standards
df = pd.read_csv("DYB_SUBSET.csv")
df = df.rename({"Event": "AE", "REDUCED_BRAND": "name", "DATE_OF_EVENT": "date"}, axis=1)

# We only need a subset of the columns for processing
df = df[["name", "date", "AE", "count"]].copy()

# %% [markdown]
# ## Processing Whole Data
#
# The simplest approach to disproportionality analyses is to consider the entire corpus of reporting as a single collection of reporting trends with potentially disproportionate representation of particular drug/device-event combinations. To run a DA method on the entire corpus, it can be processed using `convert()` which will condense data into unique drug/device-event pairs and their counts.
#
# The data container now available from the `convert()` function is compatible with the `gps()`, `bcpnn()`, `ror()` and `rfet()` analysis functions. For this analysis, we will use the multi-item gamma poisson shrinkage method `gps()`, discard any drug/device-event pairs with fewer than 3 reports, and will rank our results based on the lowers bound of the 5% posterior quantiles.

# %%
data = convert(df)
results = gps(data, min_events=3, decision_metric='rank', decision_thres=1, ranking_statistic='quantile', minimization_method="Nelder-Mead")
results.signals.head()
# Out:
#                                        Product  \
# 0                         ROTABLATOR GUIDEWIRE
# 1              PRELUDE SHORT SHEATH INTRODUCER
# 2                UNIVERSAL MICROINTRODUCER KIT
# 3      BIOSENSE WEBSTER BRAIDED GUIDING SHEATH
# 4  6F/.070" EXTRA LARGE LUMEN GUIDING CATHETER
#
#                            Adverse Event  Count  Expected Count    quantile  \
# 0                           Coating Loss    4.0        0.002642  120.112731
# 1  Risk of Blood-Borne Pathogen Exposure    7.0        0.032700   79.915761
# 2                Component Fragmentation    4.0        0.008588   79.629661
# 3          Failure to Follow Precautions    5.0        0.016515   78.866729
# 4            Cardiovascular Complication    4.0        0.009909   74.050722
#
#    count/expected  product margin  event margin       fdr       FNR        Se  \
# 0     1513.750000             4.0           4.0  0.144542  0.848225  0.158898
# 1      214.065657            22.0           9.0  0.139962  0.837552  0.747398
# 2      465.769231            13.0           4.0  0.142006  0.848082  0.162215
# 3      302.750000            20.0           5.0  0.141106  0.849980  0.427330
# 4      403.666667            10.0           6.0  0.149842  0.849105  0.152274
#
#          Sp  posterior_probability
# 0  0.853588           9.139363e-08
# 1  0.298457           5.272426e-12
# 2  0.851586           4.824520e-07
# 3  0.585248           1.095973e-08
# 4  0.854281           6.463336e-07

# %% [markdown]
# # Fine-Tuning a DA Method
#
# The base settings for all the exposed disproportionality analysis functions can be enhanced by using more appropriate prior assumptions depending on the use case. For example, instead of using the mantel-haentzel method of expected count estimation, we might consider a negative binomial model as being more appropriate. To do this, we could first calculate our dispersion and the accompanying alpha value by using the `test_dispersion()` function.

# %%
dispersion_data = test_dispersion(data)
alpha = dispersion_data["alpha"] if dispersion_data["dispersion"] > 2 else 1

nb_results = bcpnn(data, expected_method='negative-binomial', method_alpha=alpha, min_events=3)
nb_results.signals.head()
# Out:
# g:\my drive\gitstuff\vigipy\src\vigipy\utils\expectations.py:52: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   alpha = results.params[0]
#    index                      Product        Adverse Event  Count  \
# 0   2409                 RADIFOCUS II  Over-Pressurization   20.0
# 1   2024                    FAST-CATH                 Leak   47.0
# 2    121  GORE INTRODUCER SHEATH 22FR     Arterial Rupture   16.0
# 3   2057                          PSI              Leakage   23.0
# 4     55                    FAST-CATH             Air Leak   27.0
#
#    Expected Count  quantile  count/expected  product margin  event margin  \
# 0        4.650502  2.631491        4.300611           200.0          25.0
# 1        7.040947  2.307771        6.675238           445.0          76.0
# 2        4.746063  2.257721        3.371215           239.0          20.0
# 3        5.898445  2.199331        3.899332           111.0         118.0
# 4        6.168218  2.132828        4.377277           445.0          38.0
#
#         fdr       FNR        Se        Sp
# 0  0.159884  0.836633  0.697648  0.317422
# 1  0.160850  0.842351  0.631693  0.367570
# 2  0.015585  0.832410  0.039877  0.981377
# 3  0.162607  0.843201  0.655812  0.342065
# 4  0.008585  0.832523  0.026774  0.991936

# %% [markdown]
# # Using LASSO-LARS
#
# As of version 1.4, vigipy now exposes the `lasso()` method of disproportionality analysis. To use this method, a different preprocessing approach is needed for the data. The products are treated as features of the LASSO model and are therefore processed into a binary occurrence matrix. `convert_binary()` takes the same raw dataframe as input and produces the appropriate product-drug/device binary matrices.
#
# One the data container is ready, we can use `lasso()`. Lasso with the binary matrices can use either a vanilla LASSO, LASSO-LARS, or a LASSO with information criterion (AIC or BIC). You can also control confidence interval estimation through bootstrapping which is enabled by default.

# %%
bin_data = convert_binary(df)

#LASSO
ls_results = lasso(bin_data)

#LASSO-LARS
ll_results = lasso(bin_data, use_lars=True)

#LASSO-LARS + IC
lic = lasso(bin_data, use_IC=True, IC_criterion="aic")

lic.signals.head()
# Out:
# g:\my drive\gitstuff\vigipy\src\vigipy\utils\data_prep.py:129: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   event_df = event_df.groupby(by=event_df.columns, axis=1).sum()
# g:\my drive\gitstuff\vigipy\src\vigipy\utils\data_prep.py:133: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   DC.product_features = prod_df.groupby(by=prod_df.columns, axis=1).sum()
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2299: RuntimeWarning: divide by zero encountered in log
#   n_samples * np.log(2 * np.pi * self.noise_variance_)
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2300: RuntimeWarning: invalid value encountered in divide
#   + residuals_sum_squares / self.noise_variance_
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 7 iterations, alpha=1.631e-04, previous alpha=1.631e-04, with an active set of 8 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 46 iterations, alpha=3.164e-06, previous alpha=3.118e-06, with an active set of 47 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 31 iterations, alpha=1.754e-05, previous alpha=1.750e-05, with an active set of 32 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 53 iterations, alpha=1.527e-06, previous alpha=1.527e-06, with an active set of 54 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 35 iterations, alpha=2.636e-06, previous alpha=2.581e-06, with an active set of 36 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2299: RuntimeWarning: divide by zero encountered in log
#   n_samples * np.log(2 * np.pi * self.noise_variance_)
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2300: RuntimeWarning: invalid value encountered in divide
#   + residuals_sum_squares / self.noise_variance_
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 72 iterations, alpha=9.075e-07, previous alpha=9.075e-07, with an active set of 73 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 24 iterations, alpha=2.386e-06, previous alpha=2.368e-06, with an active set of 25 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 80 iterations, alpha=8.429e-07, previous alpha=8.429e-07, with an active set of 81 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 68 iterations, alpha=9.742e-07, previous alpha=9.742e-07, with an active set of 69 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 52 iterations, alpha=1.160e-06, previous alpha=1.160e-06, with an active set of 53 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2299: RuntimeWarning: divide by zero encountered in log
#   n_samples * np.log(2 * np.pi * self.noise_variance_)
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2300: RuntimeWarning: invalid value encountered in divide
#   + residuals_sum_squares / self.noise_variance_
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 90 iterations, alpha=6.907e-07, previous alpha=6.907e-07, with an active set of 91 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 92 iterations, alpha=7.696e-07, previous alpha=7.696e-07, with an active set of 93 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 82 iterations, alpha=1.646e-06, previous alpha=1.646e-06, with an active set of 83 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 48 iterations, alpha=1.312e-06, previous alpha=1.312e-06, with an active set of 49 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 41 iterations, alpha=1.451e-06, previous alpha=1.425e-06, with an active set of 42 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 94 iterations, alpha=1.595e-06, previous alpha=1.595e-06, with an active set of 95 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 85 iterations, alpha=8.202e-07, previous alpha=8.202e-07, with an active set of 86 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 111 iterations, alpha=6.545e-07, previous alpha=6.545e-07, with an active set of 112 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 50 iterations, alpha=1.415e-06, previous alpha=1.415e-06, with an active set of 51 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 37 iterations, alpha=4.009e-06, previous alpha=3.966e-06, with an active set of 38 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 86 iterations, alpha=8.178e-07, previous alpha=8.178e-07, with an active set of 87 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 32 iterations, alpha=2.416e-06, previous alpha=2.355e-06, with an active set of 33 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 89 iterations, alpha=1.605e-06, previous alpha=1.605e-06, with an active set of 90 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 69 iterations, alpha=1.065e-06, previous alpha=1.065e-06, with an active set of 70 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 44 iterations, alpha=1.606e-04, previous alpha=1.606e-04, with an active set of 45 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 26 iterations, alpha=2.950e-04, previous alpha=2.950e-04, with an active set of 27 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 44 iterations, alpha=1.605e-04, previous alpha=1.604e-04, with an active set of 45 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 54 iterations, alpha=1.743e-06, previous alpha=1.727e-06, with an active set of 53 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 108 iterations, alpha=8.099e-07, previous alpha=8.099e-07, with an active set of 109 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 51 iterations, alpha=1.876e-06, previous alpha=1.856e-06, with an active set of 50 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 56 iterations, alpha=4.184e-06, previous alpha=4.184e-06, with an active set of 57 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 77 iterations, alpha=2.078e-06, previous alpha=2.078e-06, with an active set of 78 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 79 iterations, alpha=2.340e-06, previous alpha=2.340e-06, with an active set of 78 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 94 iterations, alpha=8.698e-07, previous alpha=8.698e-07, with an active set of 95 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2299: RuntimeWarning: divide by zero encountered in log
#   n_samples * np.log(2 * np.pi * self.noise_variance_)
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2300: RuntimeWarning: invalid value encountered in divide
#   + residuals_sum_squares / self.noise_variance_
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 3 iterations, alpha=1.637e-04, previous alpha=1.637e-04, with an active set of 4 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2299: RuntimeWarning: divide by zero encountered in log
#   n_samples * np.log(2 * np.pi * self.noise_variance_)
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2300: RuntimeWarning: invalid value encountered in divide
#   + residuals_sum_squares / self.noise_variance_
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 9 iterations, alpha=1.638e-04, previous alpha=1.638e-04, with an active set of 10 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 64 iterations, alpha=1.638e-06, previous alpha=1.623e-06, with an active set of 65 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 84 iterations, alpha=2.094e-06, previous alpha=2.094e-06, with an active set of 85 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 60 iterations, alpha=1.406e-06, previous alpha=1.406e-06, with an active set of 59 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 50 iterations, alpha=1.782e-06, previous alpha=1.782e-06, with an active set of 51 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 60 iterations, alpha=2.853e-06, previous alpha=2.853e-06, with an active set of 61 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 84 iterations, alpha=2.240e-06, previous alpha=2.240e-06, with an active set of 83 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 90 iterations, alpha=3.232e-06, previous alpha=3.232e-06, with an active set of 89 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 94 iterations, alpha=4.776e-06, previous alpha=4.776e-06, with an active set of 93 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 111 iterations, alpha=1.743e-06, previous alpha=1.743e-06, with an active set of 112 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 66 iterations, alpha=1.391e-06, previous alpha=1.372e-06, with an active set of 67 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 86 iterations, alpha=1.109e-06, previous alpha=1.109e-06, with an active set of 83 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 70 iterations, alpha=4.151e-06, previous alpha=4.151e-06, with an active set of 69 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 55 iterations, alpha=1.913e-06, previous alpha=1.874e-06, with an active set of 56 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 96 iterations, alpha=9.544e-07, previous alpha=9.544e-07, with an active set of 95 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 55 iterations, alpha=2.633e-07, previous alpha=2.591e-07, with an active set of 50 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2299: RuntimeWarning: divide by zero encountered in log
#   n_samples * np.log(2 * np.pi * self.noise_variance_)
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2300: RuntimeWarning: invalid value encountered in divide
#   + residuals_sum_squares / self.noise_variance_
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2299: RuntimeWarning: divide by zero encountered in log
#   n_samples * np.log(2 * np.pi * self.noise_variance_)
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2300: RuntimeWarning: invalid value encountered in divide
#   + residuals_sum_squares / self.noise_variance_
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 91 iterations, alpha=9.872e-07, previous alpha=9.872e-07, with an active set of 90 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 110 iterations, alpha=9.086e-07, previous alpha=9.086e-07, with an active set of 109 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 48 iterations, alpha=8.116e-06, previous alpha=8.020e-06, with an active set of 49 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 134 iterations, alpha=7.714e-07, previous alpha=7.714e-07, with an active set of 133 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 118 iterations, alpha=8.404e-07, previous alpha=8.404e-07, with an active set of 117 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 27 iterations, alpha=8.383e-05, previous alpha=5.532e-05, with an active set of 28 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 66 iterations, alpha=1.491e-06, previous alpha=1.491e-06, with an active set of 67 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2299: RuntimeWarning: divide by zero encountered in log
#   n_samples * np.log(2 * np.pi * self.noise_variance_)
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2300: RuntimeWarning: invalid value encountered in divide
#   + residuals_sum_squares / self.noise_variance_
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 3 iterations, alpha=1.627e-04, previous alpha=1.627e-04, with an active set of 4 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2299: RuntimeWarning: divide by zero encountered in log
#   n_samples * np.log(2 * np.pi * self.noise_variance_)
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2300: RuntimeWarning: invalid value encountered in divide
#   + residuals_sum_squares / self.noise_variance_
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 129 iterations, alpha=2.656e-06, previous alpha=2.656e-06, with an active set of 128 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 86 iterations, alpha=6.783e-06, previous alpha=6.783e-06, with an active set of 83 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 58 iterations, alpha=6.285e-06, previous alpha=6.247e-06, with an active set of 59 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 93 iterations, alpha=4.419e-06, previous alpha=4.419e-06, with an active set of 92 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 124 iterations, alpha=2.958e-06, previous alpha=2.958e-06, with an active set of 123 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 77 iterations, alpha=4.505e-06, previous alpha=4.505e-06, with an active set of 78 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 25 iterations, alpha=1.412e-04, previous alpha=1.411e-04, with an active set of 26 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 101 iterations, alpha=3.327e-06, previous alpha=3.327e-06, with an active set of 102 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 105 iterations, alpha=3.160e-06, previous alpha=3.160e-06, with an active set of 104 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 144 iterations, alpha=8.366e-07, previous alpha=8.366e-07, with an active set of 141 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 104 iterations, alpha=2.078e-06, previous alpha=2.078e-06, with an active set of 103 regressors.
#   warnings.warn(
# ...
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 86 iterations, alpha=8.445e-07, previous alpha=8.445e-07, with an active set of 87 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2299: RuntimeWarning: divide by zero encountered in log
#   n_samples * np.log(2 * np.pi * self.noise_variance_)
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2300: RuntimeWarning: invalid value encountered in divide
#   + residuals_sum_squares / self.noise_variance_
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2299: RuntimeWarning: divide by zero encountered in log
#   n_samples * np.log(2 * np.pi * self.noise_variance_)
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2300: RuntimeWarning: invalid value encountered in divide
#   + residuals_sum_squares / self.noise_variance_
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 193 iterations, alpha=9.235e-07, previous alpha=9.235e-07, with an active set of 184 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 144 iterations, alpha=3.332e-06, previous alpha=3.332e-06, with an active set of 139 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 115 iterations, alpha=1.174e-06, previous alpha=1.174e-06, with an active set of 112 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 149 iterations, alpha=1.040e-06, previous alpha=1.040e-06, with an active set of 142 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 128 iterations, alpha=2.503e-06, previous alpha=2.503e-06, with an active set of 123 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 117 iterations, alpha=9.392e-07, previous alpha=9.392e-07, with an active set of 114 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 103 iterations, alpha=2.736e-06, previous alpha=2.736e-06, with an active set of 100 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 126 iterations, alpha=2.720e-06, previous alpha=2.720e-06, with an active set of 121 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 89 iterations, alpha=1.062e-06, previous alpha=1.062e-06, with an active set of 88 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 70 iterations, alpha=1.250e-06, previous alpha=1.250e-06, with an active set of 71 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 54 iterations, alpha=4.164e-06, previous alpha=4.164e-06, with an active set of 53 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 34 iterations, alpha=7.314e-06, previous alpha=7.292e-06, with an active set of 35 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 13 iterations, alpha=1.614e-04, previous alpha=1.614e-04, with an active set of 14 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 56 iterations, alpha=3.836e-06, previous alpha=3.799e-06, with an active set of 57 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 10 iterations, alpha=1.624e-04, previous alpha=1.624e-04, with an active set of 11 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 39 iterations, alpha=2.611e-06, previous alpha=2.581e-06, with an active set of 40 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2299: RuntimeWarning: divide by zero encountered in log
#   n_samples * np.log(2 * np.pi * self.noise_variance_)
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2300: RuntimeWarning: invalid value encountered in divide
#   + residuals_sum_squares / self.noise_variance_
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2299: RuntimeWarning: divide by zero encountered in log
#   n_samples * np.log(2 * np.pi * self.noise_variance_)
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2300: RuntimeWarning: invalid value encountered in divide
#   + residuals_sum_squares / self.noise_variance_
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 91 iterations, alpha=7.025e-07, previous alpha=7.025e-07, with an active set of 92 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 62 iterations, alpha=2.062e-06, previous alpha=2.062e-06, with an active set of 63 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 107 iterations, alpha=7.350e-07, previous alpha=7.350e-07, with an active set of 108 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 79 iterations, alpha=9.562e-07, previous alpha=9.131e-07, with an active set of 80 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 33 iterations, alpha=5.396e-06, previous alpha=5.329e-06, with an active set of 34 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 31 iterations, alpha=3.952e-06, previous alpha=3.910e-06, with an active set of 32 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 77 iterations, alpha=1.809e-06, previous alpha=1.809e-06, with an active set of 78 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 67 iterations, alpha=9.765e-07, previous alpha=9.765e-07, with an active set of 68 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2299: RuntimeWarning: divide by zero encountered in log
#   n_samples * np.log(2 * np.pi * self.noise_variance_)
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2300: RuntimeWarning: invalid value encountered in divide
#   + residuals_sum_squares / self.noise_variance_
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2299: RuntimeWarning: divide by zero encountered in log
#   n_samples * np.log(2 * np.pi * self.noise_variance_)
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2300: RuntimeWarning: invalid value encountered in divide
#   + residuals_sum_squares / self.noise_variance_
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2299: RuntimeWarning: divide by zero encountered in log
#   n_samples * np.log(2 * np.pi * self.noise_variance_)
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2300: RuntimeWarning: invalid value encountered in divide
#   + residuals_sum_squares / self.noise_variance_
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2299: RuntimeWarning: divide by zero encountered in log
#   n_samples * np.log(2 * np.pi * self.noise_variance_)
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2300: RuntimeWarning: invalid value encountered in divide
#   + residuals_sum_squares / self.noise_variance_
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2299: RuntimeWarning: divide by zero encountered in log
#   n_samples * np.log(2 * np.pi * self.noise_variance_)
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2300: RuntimeWarning: invalid value encountered in divide
#   + residuals_sum_squares / self.noise_variance_
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2299: RuntimeWarning: divide by zero encountered in log
#   n_samples * np.log(2 * np.pi * self.noise_variance_)
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2300: RuntimeWarning: invalid value encountered in divide
#   + residuals_sum_squares / self.noise_variance_
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2299: RuntimeWarning: divide by zero encountered in log
#   n_samples * np.log(2 * np.pi * self.noise_variance_)
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2300: RuntimeWarning: invalid value encountered in divide
#   + residuals_sum_squares / self.noise_variance_
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 115 iterations, alpha=9.061e-07, previous alpha=9.061e-07, with an active set of 112 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 66 iterations, alpha=1.546e-06, previous alpha=1.546e-06, with an active set of 67 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 94 iterations, alpha=9.829e-07, previous alpha=9.829e-07, with an active set of 95 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 79 iterations, alpha=2.669e-06, previous alpha=2.608e-06, with an active set of 80 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 83 iterations, alpha=1.281e-06, previous alpha=1.281e-06, with an active set of 82 regressors.
#   warnings.warn(
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2299: RuntimeWarning: divide by zero encountered in log
#   n_samples * np.log(2 * np.pi * self.noise_variance_)
# C:\Users\shake\anaconda3\envs\vigipy\lib\site-packages\sklearn\linear_model\_least_angle.py:2300: RuntimeWarning: invalid value encountered in divide
#   + residuals_sum_squares / self.noise_variance_
#                                                Product        Adverse Event  \
# 168710           MONARCH IOL DELIVERY SYSTEM-CARTRIDGE         Device Stuck
# 13724                    6F 11 CM IMPUT INTRODUCER KIT    Allergic Reaction
# 626600  SOFT TISSUE BIOPSY CO-AXIAL INTRODUCER NEEDLES  Unintended Movement
# 97030                             ROTABLATOR GUIDEWIRE         Coating Loss
# 40847                        CROSSFLEX LC 4.0X22/ 25MM      Balloon Rupture
#
#         LASSO Coefficient  CI Lower  CI Upper
# 168710                1.0     0.225       1.0
# 13724                 1.0     0.000       1.0
# 626600                1.0     0.000       1.0
# 97030                 1.0     1.000       1.0
# 40847                 1.0     0.000       1.0

# %% [markdown]
# # GLM-based LASSO
#
# A fourth type of newly-support LASSO is the GLM-based LASSO. In this approach, rather than binarizing the event data in addition to the product data, only the product data is binarized while the event data retains its count information. This enables use of a negative-binomial family GLM to identify the relevant features in the product matrix.

# %%
count_data = convert_binary(df, use_counts=True)
glm_results = lasso(count_data, use_glm=True, lasso_alpha=.001, lasso_thresh=0)
glm_results.signals.head()
# Out:
# g:\my drive\gitstuff\vigipy\src\vigipy\utils\data_prep.py:133: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   DC.product_features = prod_df.groupby(by=prod_df.columns, axis=1).sum()

# %% [markdown]
# # Turning any Model into a Time Series Observer
#
# As mentioned eariler, the naive approach to DA is to consider the entire corpus simultaneously when identifying signals. A more nuanced approach might be to analyze the development of a signal over time. To provide this time-based analysis, vigipy exposes the `LongitudinalModel()` class which allows the selection of a time step (i.e. yearly, quarterly, monthly, etc) and splits the data into discrete groups. To do this, a `date` column must be available in the original input data before creating the `LongitudinalModel`. Once initialized, the class provides two major types of time-series analysis:
#
# ### Cumulative Analysis
# The cumulative analysis method, exposed by `LongitudinalModel.run()` assumes that at each time group, the previously reported events and products all contribute to the overall pattern of potentially disproportionate reporting. Thus each time step rolls up all cumulative previous reports into the analysis. The most recent time step would therefore be equivalent to running the whole data at once as was done above.
#
# ### Disjoint Analysis
# Another way to consider analysis DA time data is that signals may periodically spike, independent of the previous patterns or signals. `LongitudinalModel.run_disjoint()` processes only a single time step independent of the previous or future data. This provides less data at each step, but may be more sensitive to rapid changes in reported events.
#
# ### Handling Gaps
# It is common that some DA datasets or vigilance networks will have very sparse periods of reporting. In these cases, the default behavior of the `LongitudinalModel` is to skip the time slice and represent the signal data as a `None`. This allows users to programatically maintain the same timestep structure in the output and identify those periods of sparsity. By setting `include_gaps` to `False`, the `run()` and `run_disjoint()` methods will instead skip these time steps entirely and not provide an empty representation.

# %%
#Initialize the model with the data and a yearly time step.
LM = LongitudinalModel(df, "YE")
LM.date_groups.sum().head()

# %%
LM.run_disjoint(bcpnn, include_gaps=False, expected_method='negative-binomial', method_alpha=alpha, min_events=3)
for timestamp, container in LM.results:
    print(container.signals.iloc[0])
